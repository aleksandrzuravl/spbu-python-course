# %% [markdown]
# # BIG MATRIX

# %%
import numpy as np

n = 1500

x = np.linspace(0, 8*np.pi, n)
y = np.linspace(0, 8*np.pi, n)
X, Y = np.meshgrid(x, y)

matrix = (np.sin(X) * np.cos(3*Y) + 
          np.exp(-0.1*X) * np.sin(0.5*Y) + 
          0.3 * np.cos(2*X + Y) + 
          0.4 * np.tanh(0.2*X*Y) +
          0.1 * np.random.randn(n, n))

np.fill_diagonal(matrix, matrix.diagonal() + 2.0)


matrix[-1, -1] = 2.71828  

print(f"Размер матрицы: {matrix.shape}")
print(f"Количество элементов: {matrix.size:,}")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 x = np.linspace(0, 8*np.pi, n)
#       6 y = np.linspace(0, 8*np.pi, n)
# ----> 7 X, Y = np.meshgrid(x, y)
#       9 matrix = (np.sin(X) * np.cos(3*Y) +
#      10           np.exp(-0.1*X) * np.sin(0.5*Y) +
#      11           0.3 * np.cos(2*X + Y) +
#      12           0.4 * np.tanh(0.2*X*Y) +
#      13           0.1 * np.random.randn(n, n))
#      15 np.fill_diagonal(matrix, matrix.diagonal() + 2.0)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:5280, in meshgrid(copy, sparse, indexing, *xi)
#    5277     output = np.broadcast_arrays(*output, subok=True)
#    5279 if copy:
# -> 5280     output = tuple(x.copy() for x in output)
#    5282 return output
#
# ...
